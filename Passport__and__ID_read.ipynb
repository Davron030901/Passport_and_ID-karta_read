# %% [markdown]
# <a href="https://colab.research.google.com/github/Davron030901/Passport_and_ID-karta_read/blob/main/Passport__and__ID_read.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # """Passport Ma'lumotlarini O'qish"""

# %% [markdown]
# ## Kutubxonalarni yuklash

# %%
# !pip install easyocr
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 28.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 69.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 53.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 39.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 52.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 422.9/422.9 kB 21.9 MB/s eta 0:00:00
# ...

# %%
import cv2
import easyocr
import matplotlib.pyplot as plt
import numpy as np
import re
import torch

# %% [markdown]
# ## Rasmni yuklash

# %%
def download_image(url, filename):
    # !wget {url} -O {filename}

# %% [markdown]
# ## OCR ni ishga tushirish

# %%
def process_image(image_path, lang='uz', gpu=True):
    img = cv2.imread(image_path)
    reader = easyocr.Reader([lang], gpu=gpu)
    text_ = reader.readtext(img)
    return text_, img

# %% [markdown]
# ## Ma'lumotlarni **ajratish**

# %%
def extract_info(text, pattern):
    match = re.search(pattern, text)
    return match.group() if match else None

# %% [markdown]
# ## Passport uchun rasmni yuklash

# %%
download_image(
    "https://raw.githubusercontent.com/Davron030901/Passport_and_ID-karta_read/main/text-detection-python-tesseract-easyocr-textract/uzb_passport.jpg",
    "uzb_passport.jpg"
)
# Out:
# --2025-02-06 07:10:23--  https://raw.githubusercontent.com/Davron030901/Passport_and_ID-karta_read/main/text-detection-python-tesseract-easyocr-textract/uzb_passport.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1800786 (1.7M) [image/jpeg]
# Saving to: ‘uzb_passport.jpg’
#
# uzb_passport.jpg    100%[===================>]   1.72M  --.-KB/s    in 0.02s
#
# 2025-02-06 07:10:23 (70.0 MB/s) - ‘uzb_passport.jpg’ saved [1800786/1800786]

# %% [markdown]
# ## OCR ni ishga tushirish

# %%
text_, img = process_image("uzb_passport.jpg", lang='uz', gpu=torch.cuda.is_available())

# %% [markdown]
# ## Natijalarni chop etish

# %%
threshold = 0.25
for bbox, text, score in text_:
    if score > threshold:
        print(f"Aniqlangan matn: {text}")
        cv2.putText(img, text, [int(j) for j in bbox[0]], cv2.FONT_HERSHEY_COMPLEX, 2.5, (0, 0, 255), 5)

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# Aniqlangan matn: O'ZBEKISTON
# Aniqlangan matn: RESPUBLIKASI
# Aniqlangan matn: FAMILIYASI
# Aniqlangan matn: RAYKOV
# Aniqlangan matn: ISMI
# Aniqlangan matn: JINSI
# Aniqlangan matn: ALEKSANDR
# Aniqlangan matn: ERKAK
# Aniqlangan matn: OTASINING ISMI
# Aniqlangan matn: VADIMOVICH
# Aniqlangan matn: TUGILGAN SANASI
# Aniqlangan matn: TUG'ILGAN JOYI
# Aniqlangan matn: 09
# Aniqlangan matn: 12
# Aniqlangan matn: 1989
# Aniqlangan matn: TOSHKENT
# Aniqlangan matn: MILLATI
# Aniqlangan matn: RUS
# Aniqlangan matn: KIM TOMONIDAN BERILGAN
# Aniqlangan matn: ToShKENT
# Aniqlangan matn: SHAHAR
# Aniqlangan matn: MIRZO-ULUG
# Aniqlangan matn: BEK
# Aniqlangan matn: TUMANI
# Aniqlangan matn: IIB
# Aniqlangan matn: SHAXSIY IMZO / HOLDER'S SIGNATURE
# Aniqlangan matn: O'ZBEKISTON
# Aniqlangan matn: RESPUBLIKASI
# Aniqlangan matn: REPUBLIC
# Aniqlangan matn: OF
# Aniqlangan matn: UZBEKISTAN
# Aniqlangan matn: TURI / TYPE
# Aniqlangan matn: DAVLAT KODI / COUNTRY CODE
# ...

# %% [markdown]
# ##FIO, Passport Seria raqamini va JSHR ni *aniqlash*

# %%
text_
# Out:
# [([[789, 700], [1486, 700], [1486, 805], [789, 805]],
#   "O'ZBEKISTON",
#   0.8807443205147217),
#  ([[1530, 698], [2297, 698], [2297, 801], [1530, 801]],
#   'RESPUBLIKASI',
#   0.9999180607663755),
#  ([[208, 803], [438, 803], [438, 855], [208, 855]],
#   'FAMILIYASI',
#   0.999052330786766),
#  ([[239, 875], [568, 875], [568, 955], [239, 955]],
#   'RAYKOV',
#   0.9455596465217905),
#  ([[202, 983], [295, 983], [295, 1023], [202, 1023]],
#   'ISMI',
#   0.9995035529136658),
#  ([[2340, 973], [2443, 973], [2443, 1016], [2340, 1016]],
#   'JINSI',
#   0.9997536949101179),
#  ([[239, 1057], [729, 1057], [729, 1137], [239, 1137]],
#   'ALEKSANDR',
#   0.9925073925893829),
#  ([[2384, 1071], [2662, 1071], [2662, 1150], [2384, 1150]],
#   'ERKAK',
#   0.9997397800581924),
#  ([[204, 1154], [525, 1154], [525, 1205], [204, 1205]],
#   'OTASINING ISMI',
#   0.7962140438737876),
#  ([[234, 1225], [785, 1225], [785, 1314], [234, 1314]],
#   'VADIMOVICH',
#   0.9081613150923098),
# ...

# %%
F=text_[3][1]
I=text_[6][1]
O=text_[9][1]

# %%
read_last_text=text_[-1][-2]

# %%
passport_number = text[:9]
jshr = text[-16:-2]

print(f"Passport Seria va Raqami: {passport_number}")
print(f"JSHR: {jshr}")
print(f"F.I.O: {F} {I} {O}")
# Out:
# Passport Seria va Raqami: AA5737888
# JSHR: 30912890270322
# F.I.O: RAYKOV ALEKSANDR VADIMOVICH

# %% [markdown]
# #"""ID Karta Ma'lumotlarini O'qish"""

# %% [markdown]
# ## Rasmni yuklash

# %%
def download_image(url, filename):
    # !wget {url} -O {filename}

# %% [markdown]
# ## OCR ni ishga tushirish

# %%
def process_image(image_path, lang='en', gpu=True):
    img = cv2.imread(image_path)
    reader = easyocr.Reader([lang], gpu=gpu)
    text_ = reader.readtext(img)
    return text_, img

# %% [markdown]
# ## ID karta uchun rasmni yuklash

# %%
download_image(
    "https://raw.githubusercontent.com/Davron030901/Passport_and_ID-karta_read/main/text-detection-python-tesseract-easyocr-textract/ID_karta.jpg",
    "ID_karta.jpg"
)
# Out:
# --2025-02-06 07:21:47--  https://raw.githubusercontent.com/Davron030901/Passport_and_ID-karta_read/main/text-detection-python-tesseract-easyocr-textract/ID_karta.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35354 (35K) [image/jpeg]
# Saving to: ‘ID_karta.jpg’
#
# ID_karta.jpg        100%[===================>]  34.53K  --.-KB/s    in 0.004s
#
# 2025-02-06 07:21:47 (9.03 MB/s) - ‘ID_karta.jpg’ saved [35354/35354]

# %% [markdown]
# ## Ma'lumotlarni ajratish

# %%
def extract_info(text, pattern):
    match = re.search(pattern, text)
    return match.group() if match else None

# %% [markdown]
# ## OCR ni ishga tushirish

# %%
text_, img = process_image("ID_karta.jpg", lang='en', gpu=False)
# Out:
# WARNING:easyocr.easyocr:Using CPU. Note: This module is much faster with a GPU.
# WARNING:easyocr.easyocr:Downloading recognition model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete

# %%
for bbox, text, score in text_:
    if score > threshold:
        cv2.putText(img, text, [int(j) for j in bbox[0]], cv2.FONT_HERSHEY_COMPLEX, 1, (0, 0, 255), 2)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
text_
# Out:
# [([[124, 10], [484, 10], [484, 40], [124, 40]],
#   "O'ZBEKISTON RESPUBLIKASI",
#   0.723892088784732),
#  ([[124, 35], [408, 35], [408, 64], [124, 64]],
#   'SHAXS GUVOHNOMASI',
#   0.6352078331626557),
#  ([[231, 119], [339, 119], [339, 139], [231, 139]],
#   'NURSAIDOV',
#   0.9325757850156694),
#  ([[232, 160], [326, 160], [326, 184], [232, 184]],
#   'NURIDDIN',
#   0.9954356452950378),
#  ([[322, 200], [384, 200], [384, 226], [322, 226]],
#   "0'GLI",
#   0.6866538439894063),
#  ([[287, 239], [323, 239], [323, 253], [287, 253]],
#   'Oca',
#   0.055170459098125055),
#  ([[335, 235], [411, 235], [411, 251], [335, 251]],
#   'Datr 0 Gith',
#   0.060650665146905376),
#  ([[228, 246], [336, 246], [336, 270], [228, 270]],
#   '13.05.1995',
#   0.8588558665440045),
#  ([[634, 236], [698, 236], [698, 268], [634, 268]],
#   'ERKAK',
#   0.5675416369600953),
#  ([[233, 283], [283, 283], [283, 297], [233, 297]],
#   'LEn',
#   0.06420288123174277),
# ...

# %% [markdown]
# ## Natijalarni chop etish

# %%
threshold = 0.25
combined_text = ' '.join(t[1] for t in text_)
print(f"Aniqlangan umumiy matn: {combined_text}")
# Out:
# Aniqlangan umumiy matn: O'ZBEKISTON RESPUBLIKASI SHAXS GUVOHNOMASI NURSAIDOV NURIDDIN 0'GLI Oca Datr 0 Gith 13.05.1995 ERKAK LEn [nle 05 13,01.2021 0 zbekiston Ane men Dat 030 0 FPl 0ai 12.01.2031 AD 2330030 YASHNAR'

# %% [markdown]
# ## F.I.O ni aniqlash

# %%
ism=text_[3][1]
familaiya=text_[2][1]
otasi=text_[-1][1]

# %%
FIO=f" {familaiya} {ism} {otasi}"

# %% [markdown]
# ## ID raqamini aniqlash

# %%
id_seria_number= text_[-2][1]

# %% [markdown]
# ## Natijalarni chop etish

# %%
print(f"F.I.O: {FIO} o'g'li")
print(f"ID Seria Raqami: {id_seria_number}")
# Out:
# F.I.O:  NURSAIDOV NURIDDIN YASHNAR' o'g'li
# ID Seria Raqami: AD 2330030
